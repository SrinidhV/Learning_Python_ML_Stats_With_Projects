# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\vudit\OneDrive\Desktop\Data Science\Python Practice\Pandas\Learning Pandas\Reading In Files in Pandas\Customer Call List.xlsx", sheet_name = 'Call List')

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %% [markdown]
# To remove duplicates

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %% [markdown]
# To drop a column

# %%
df = df.drop(columns = ['Not_Useful_Column'])
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %% [markdown]
# Strip Unnecessary Characters

# %%
df['Last_Name'] = df['Last_Name'].str.strip() # By default it removes only white spaces
df['Last_Name'] = df['Last_Name'].str.lstrip(".") # Removes the ... from left side of the string
df['Last_Name'] = df['Last_Name'].str.rstrip("_")
df['Last_Name'] = df['Last_Name'].str.strip("/")

# Strip works like a RE. We can directly remove all of the stuff by mentioning in a single paranthesis

df['Last_Name'] = df['Last_Name'].str.strip("/._ ") # This alone does the work of all the above 4 statements
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %% [markdown]
# Using regex to replace stuff

# %%
#Before we use .str and regex to replace stuff, we need everything to be a string in that column
df['Phone_Number'] = df['Phone_Number'].astype('string')

df['Phone_Number'] = df['Phone_Number'].str.replace('[^0-9]' , '', regex = True).fillna('')
df['Phone_Number'].apply(type).value_counts()

df['Phone_Number'] = df['Phone_Number'].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:])
df['Phone_Number'] = df['Phone_Number'].replace('--', '')

df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent  706-695-0392
# ...

# %% [markdown]
# Splitting Columns

# %%
df[["Street","State","Zipcode"]]= df['Address'].str.split(pat=',', n=2, expand=True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent  706-695-0392
# ...

# %%
df[['Paying Customer','Do_Not_Contact']] = df[['Paying Customer','Do_Not_Contact']].replace(['Y','N','N/a'], ['Yes','No','']).fillna('')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent  706-695-0392
# ...

# %%
df= df.fillna('') # Nan And None value's are considered as na
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White  706-695-0392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter  706-695-0392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent  706-695-0392
# ...

# %% [markdown]
# To drop rows based on a filter. We can also we for loop

# %%
a = df[df['Do_Not_Contact'] == 'Yes'].index
b= df[df['Phone_Number'] == ''].index
df.drop(a,inplace= True)
df.drop(b,inplace= True)
df['Do_Not_Contact'] = df['Do_Not_Contact'].replace('', 'No')
df.drop(['Address'], axis = 1)
df.reset_index(drop  =True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 4
#       2 b= df[df['Phone_Number'] == ''].index
#       3 df.drop(a,inplace= True)
# ----> 4 df.drop(b,inplace= True)
#       5 df['Do_Not_Contact'] = df['Do_Not_Contact'].replace('', 'No')
#       6 df.drop(['Address'], axis = 1)
#
# File c:\Users\vudit\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
# ...

# %% [markdown]
# Data Cleaning on Layoffs Dataset

# %% [markdown]
# Task 1 - Data Understanding

# %%
df= pd.read_csv(r"C:\Users\vudit\OneDrive\Desktop\Data Science\Projects\SQL Projects\Data Cleaning Project\layoffs.csv")

# %%
df.head()
df.describe()
df.info()
df_org = df.copy()
df['industry'].value_counts(dropna= False)
df.nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2361 entries, 0 to 2360
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   company                2361 non-null   object
#  1   location               2361 non-null   object
#  2   industry               2357 non-null   object
#  3   total_laid_off         1621 non-null   float64
#  4   percentage_laid_off    1576 non-null   float64
#  5   date                   2360 non-null   object
#  6   stage                  2355 non-null   object
#  7   country                2361 non-null   object
#  8   funds_raised_millions  2152 non-null   float64
# dtypes: float64(3), object(6)
# memory usage: 166.1+ KB
# company                  1893
# location                  191
# industry                   32
# total_laid_off            285
# percentage_laid_off        73
# date                      483
# stage                      16
# ...

# %% [markdown]
# Task 2 -Working with NULL values

# %%
#df[df['company'].isin(['Airbnb','Bally\'s Interactive', 'Juul','Carvana'])].sort_values(by = 'company')
df[df['stage'].isnull()]
# Out:
#             company       location    industry  total_laid_off  \
# 9          Accolade        Seattle  Healthcare             NaN
# 10           Indigo         Boston       Other             NaN
# 16         Flipkart      Bengaluru      Retail             NaN
# 18    Truckstop.com          Boise   Logistics             NaN
# 57    Arch Oncology      St. Louis  Healthcare             NaN
# ...             ...            ...         ...             ...
# 2334          Zwift    Los Angeles     Fitness             NaN
# 2340         Vacasa       Portland      Travel             NaN
# 2345      Anyvision       Tel Aviv    Security             NaN
# 2347  Tuft & Needle        Phoenix      Retail             NaN
# 2359         Casper  New York City      Retail             NaN
#
#       percentage_laid_off       date     stage         country  \
# 9                     NaN   3/3/2023  Post-IPO   United States
# 10                    NaN   3/3/2023  Series F  United States.
# ...

# %%
#Filling the Nan industry values from similar companies
a=df.sort_values(by ='company')
df['industry'] = df.groupby('company')['industry'].bfill()

df[df['company'].isin(['Airbnb','Juul'])]



#Checking the numeric column for nulls
b = df[df['total_laid_off'].isnull() & df['percentage_laid_off'].isnull()].index
df=df.drop(index = b)
# Out:
# Empty DataFrame
# Columns: [company, location, industry, total_laid_off, percentage_laid_off, date, stage, country, funds_raised_millions]
# Index: []

# %% [markdown]
# Task 4 - Removing Duplicates

# %%
duplicate_columns = [
    'company', 'location', 'industry', 'total_laid_off',
    'percentage_laid_off', 'date', 'stage', 'country', 'funds_raised_millions'
]

df=df.drop_duplicates(subset = duplicate_columns)
# Out:
#             company        location        industry  total_laid_off  \
# 0         Atlassian          Sydney           Other           500.0
# 1          SiriusXM   New York City           Media           475.0
# 2            Alerzo          Ibadan          Retail           400.0
# 3            UpGrad          Mumbai       Education           120.0
# 4              Loft       Sao Paulo     Real Estate           340.0
# ...             ...             ...             ...             ...
# 2352   HopSkipDrive     Los Angeles  Transportation             8.0
# 2353    Panda Squad     SF Bay Area        Consumer             6.0
# 2354  Tamara Mellon     Los Angeles          Retail            20.0
# 2355       EasyPost  Salt Lake City       Logistics            75.0
# 2356      Blackbaud      Charleston           Other           500.0
#
#       percentage_laid_off       date     stage        country  \
# 0                    0.05   3/6/2023  Post-IPO      Australia
# ...

# %% [markdown]
# Task 5-Standardizing values

# %%
df['industry'].value_counts(dropna=False) # Show counts including NaN if any

df['industry'] = df['industry'].str.replace(r'Crypto.*', 'Crypto', regex = True)

df[df['industry'].str.startswith('Crypto', na=False)]['industry'].unique()
# Out:
# array(['Crypto'], dtype=object)

# %%
crypto_industries_mask = df_org['industry'].str.startswith('Crypto', na=False)
crypto_industries_initial_df = df_org[crypto_industries_mask]
crypto_industries_initial_df['industry'].unique()
# Out:
# array(['Crypto', 'Crypto Currency', 'CryptoCurrency'], dtype=object)

# %%
df['country'] = df['country'].str.replace(r'United States.*', 'United States' , regex =True)
df['country'].unique()

df['country'] = df['country'].str.strip()
